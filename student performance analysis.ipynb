# %%
# Importing libraries
import pandas as pd
import numpy as np
import scipy
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Working Procedure

# %% [markdown]
# #### data description > Feature selection > Feature customization > Drop feature
# #### invividual feature engineering

# %%
#import data set
data = pd.read_csv("Students performance survey.csv")

# %% [markdown]
# # Data description

# %%
data.head(10)
# Out:
#          ID                      Name  Gender Age H.S.C passing year  \
# 0  18303059                Abu Raihan    Male  24               2016
# 1  21203066       Jahidul Islam Anik     Male  22               2020
# 2  20103005  Symu Alahi Jannat Abonti  Female  21               2019
# 3  21203080     Hedayetul Islam Anik     Male  20               2020
# 4  21203032           Abu Aslam Mithu    Male  22               2019
# 5  21203073    Shahriyar Islam Shohan    Male  20               2020
# 6  21203059     Md Abdul Ahad Linkon     Male  22               2018
# 7  21203012         Mst.Nur-E-Jannat   Female  22               2019
# 8  21203054        Alif Hasan Prodip     Male  20               2020
# 9  21203002              Nusrat Jahan  Female  22    Diploma degree
#
#   University Admission year  \
# 0                      2018
# 1                      2021
# 2                      2020
# 3                      2021
# 4                      2021
# 5                      2021
# ...

# %%
data.describe()
# Out:
#        Current Semester  How many hour do you study daily?  \
# count        675.000000                         675.000000
# mean           5.200000                           3.330370
# std            3.874898                           1.904753
# min            1.000000                           0.000000
# 25%            2.000000                           2.000000
# 50%            3.000000                           3.000000
# 75%            8.000000                           4.000000
# max           22.000000                          30.000000
#
#        How many times do you seat for study in a day?  \
# count                                      675.000000
# mean                                         2.151111
# std                                          1.120742
# min                                          0.000000
# 25%                                          1.000000
# 50%                                          2.000000
# ...

# %%
#see the null value
data.isnull().sum()
# Out:
# ID                                                                              0
# Name                                                                            0
# Gender                                                                          0
# Age                                                                             0
# H.S.C passing year                                                              0
# University Admission year                                                       0
# University Name                                                                 0
# Program                                                                         0
# Current Semester                                                                0
# Do you have meritorious scholarship ?                                           0
# Do you use University transportation?                                           5
# ...

# %%
# show the null values

sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 43 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   ID                                                                          675 non-null    object
#  1   Name                                                                        675 non-null    object
#  2   Gender                                                                      675 non-null    object
#  3   Age                                                                         675 non-null    object
#  4   H.S.C passing year                                                          675 non-null    object
#  5   University Admission year                                                   675 non-null    object
# ...

# %% [markdown]
# # Feature Engineering

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 43 columns):
#  #   Column                                                                      Non-Null Count  Dtype
# ---  ------                                                                      --------------  -----
#  0   ID                                                                          675 non-null    object
#  1   Name                                                                        675 non-null    object
#  2   Gender                                                                      675 non-null    object
#  3   Age                                                                         675 non-null    object
#  4   H.S.C passing year                                                          675 non-null    object
#  5   University Admission year                                                   675 non-null    object
# ...

# %% [markdown]
# #### Renaming column names

# %%
data=data.rename(columns={'How many Credit did you have completed?':'comp_Cred','What is your current CGPA?':'CGPA',
                        'What is your hometown?':'Hometown','What was your previous SGPA?':'pre_sgpa',
                          'Are you self dependent?':'self_dep','How many family members you have?':'family_mem',
                          'What is your monthly family income?':'Family_inc','Do you have any physical disabilities?':'Phy_disb',
                          'Did you ever perform in any team oriented task?':'team_task',
                          'Do you have any health issues?':'phy_issue',
                          'Do you have any political engagement?':'political_eng',
                          'Do you have any kids?':'kids',
                          'With whom you are living with?':'living_sts',
                          'Are you engaged with any co-curriculum activities?':'curri_act',
                          'What is your relationship status?':'relation_sts',
                          'How many hour do you spent daily on your skill development?':'skill_dev_hour',
                          'What are the skills do you have ?':'skills',
                          'Do you attend in teacher consultancy for any kind of academical problems? ':'faculty_consultency',
                          'Did you ever got suspension?':'suspensioN',
                          'Did you ever fall in probation?':'proBation',
                          'Average attendance on class':'attendance',
                          'Status of your English language proficiency':'English_skill',
                          'How many hour do you spent daily in social media?':'social_media_time',
                          'Do you have personal Computer?':'Have_PC',
                          'Do you use smart phone?':'have_smart_device',
                          'What is your preferable learning mode?':'learning_mode',
                          'How many times do you seat for study in a day?':'freq_study/day',
                          'How many hour do you study daily?':'study_hour/day',
                          'Do you use University transportation?':'use_uni_transport',
                          'Do you have meritorious scholarship ?':'merit_scholarship',
                          'Current Semester':'curr_sem','University Name':'uni_name',
                          'University Admission year':'uni_admssn_year',
                          'H.S.C passing year':'hsc_pass_year'
                          
                       },inplace=False)

# %%
#data.rename({'What is your current CGPA?':'CGPA'},axis=1)
data.head()
# Out:
#          ID                      Name  Gender Age hsc_pass_year  \
# 0  18303059                Abu Raihan    Male  24          2016
# 1  21203066       Jahidul Islam Anik     Male  22          2020
# 2  20103005  Symu Alahi Jannat Abonti  Female  21          2019
# 3  21203080     Hedayetul Islam Anik     Male  20          2020
# 4  21203032           Abu Aslam Mithu    Male  22          2019
#
#   uni_admssn_year uni_name Program  curr_sem merit_scholarship  ... phy_issue  \
# 0            2018    IUBAT    BCSE        12               Yes  ...        No
# 1            2021   IUBAT     BCSE         4               Yes  ...        No
# 2            2020    IUBAT    BCSE         5                No  ...        No
# 3            2021    IUBAT    BCSE         4               Yes  ...       Yes
# 4            2021    IUBAT    BCSE         4               Yes  ...       Yes
#
#    team_task  Phy_disb                         Family_inc family_mem self_dep  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 43 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   ID                                                                  675 non-null    object
#  1   Name                                                                675 non-null    object
#  2   Gender                                                              675 non-null    object
#  3   Age                                                                 675 non-null    object
#  4   hsc_pass_year                                                       675 non-null    object
#  5   uni_admssn_year                                                     675 non-null    object
#  6   uni_name                                                            675 non-null    object
# ...

# %%
#lowercase all columns name
data.rename(columns=str.lower, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 43 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   id                                                                  675 non-null    object
#  1   name                                                                675 non-null    object
#  2   gender                                                              675 non-null    object
#  3   age                                                                 675 non-null    object
#  4   hsc_pass_year                                                       675 non-null    object
#  5   uni_admssn_year                                                     675 non-null    object
#  6   uni_name                                                            675 non-null    object
# ...

# %% [markdown]
# #### dropping feature

# %%
data.drop(["what is your mother's occupation?"],axis=1,inplace=True)

# %%
data.drop(["what is your father's occupation?"],axis=1,inplace=True)

# %%
data.drop(["what is you interested area?"],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 40 columns):
#  #   Column                                                              Non-Null Count  Dtype
# ---  ------                                                              --------------  -----
#  0   id                                                                  675 non-null    object
#  1   name                                                                675 non-null    object
#  2   gender                                                              675 non-null    object
#  3   age                                                                 675 non-null    object
#  4   hsc_pass_year                                                       675 non-null    object
#  5   uni_admssn_year                                                     675 non-null    object
#  6   uni_name                                                            675 non-null    object
# ...

# %%
data.drop(['please write down the topic name you are comfortable to talk with '],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 39 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    object
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    object
#  5   uni_admssn_year      675 non-null    object
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    object
#  10  use_uni_transport    670 non-null    object
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    object
#  14  have_smart_device    675 non-null    object
# ...

# %%
# show the null values
plt.title('Heatmap for Null value')
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:title={'center':'Heatmap for Null value'}>

# %%
data.isnull().sum()
# Out:
# id                       0
# name                     0
# gender                   0
# age                      0
# hsc_pass_year            0
# uni_admssn_year          0
# uni_name                 0
# program                  0
# curr_sem                 0
# merit_scholarship        0
# use_uni_transport        5
# study_hour/day           0
# freq_study/day           0
# learning_mode            0
# have_smart_device        0
# have_pc                  0
# social_media_time        0
# english_skill            0
# attendance               0
# probation                0
# suspension               0
# faculty_consultency      0
# skills                   1
# skill_dev_hour           0
# relation_sts             0
# curri_act               12
# living_sts               0
# kids                     0
# political_eng            0
# phy_issue                0
# team_task                0
# phy_disb                 0
# family_inc               1
# family_mem               1
# ...

# %%
data['use_uni_transport']
# Out:
# 0       No
# 1      Yes
# 2       No
# 3       No
# 4       No
#       ...
# 670     No
# 671     No
# 672    Yes
# 673    Yes
# 674    Yes
# Name: use_uni_transport, Length: 675, dtype: object

# %% [markdown]
# #### fill up null values

# %%
data['use_uni_transport'] = data['use_uni_transport'].fillna(data['use_uni_transport'].mode()[0])

# %%
#skills
data['skills'] = data['skills'].fillna(data['skills'].mode()[0])

# %%
data['family_inc'] = data['family_inc'].fillna(data['family_inc'].mode()[0])

# %%
data['family_mem'] = data['family_mem'].fillna(data['family_mem'].mode()[0])

# %%
#curri_act
data['curri_act'] = data['curri_act'].fillna(data['curri_act'].mode()[0])

# %%
data.isnull().sum()
# Out:
# id                       0
# name                     0
# gender                   0
# age                      0
# hsc_pass_year            0
# uni_admssn_year          0
# uni_name                 0
# program                  0
# curr_sem                 0
# merit_scholarship        0
# use_uni_transport        0
# study_hour/day           0
# freq_study/day           0
# learning_mode            0
# have_smart_device        0
# have_pc                  0
# social_media_time        0
# english_skill            0
# attendance               0
# probation                0
# suspension               0
# faculty_consultency      0
# skills                   0
# skill_dev_hour           0
# relation_sts             0
# curri_act                0
# living_sts               0
# kids                     0
# political_eng            0
# phy_issue                0
# team_task                0
# phy_disb                 0
# family_inc               0
# family_mem               0
# ...

# %%
pd.value_counts(data['use_uni_transport'])
# Out:
# No     346
# Yes    329
# Name: use_uni_transport, dtype: int64

# %%
# show the null values
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 39 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    object
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    object
#  5   uni_admssn_year      675 non-null    object
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    object
#  10  use_uni_transport    675 non-null    object
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    object
#  14  have_smart_device    675 non-null    object
# ...

# %% [markdown]
# # Individual feature engineering

# %% [markdown]
# ##### Feature engineering for hsc_pass_year column

# %%
pd.value_counts(data['hsc_pass_year'])
# Out:
# 2020                                       292
# 2019                                       164
# 2018                                        94
# 2017                                        44
# 2016                                        22
# 2021                                        14
# 2014                                        10
# 2015                                         5
# Diploma 2020                                 2
# 2013                                         2
# 2022                                         2
# Diploma (2021)                               1
# Diploma  2019                                1
# 2017(Diploma in Engineering)                 1
# W                                            1
# Completed Diploma ( 2021)                    1
# Diploma-2018                                 1
# 2020 (Diploma)                               1
# 2019-2020 batch passing year 2021            1
# 2017 (DIPLOMA)                               1
# ...

# %%
data['hsc_pass_year'].replace('2014-2016', '2015',inplace=True)

# %%
data['hsc_pass_year'].replace('Diploma-2018', '2018',inplace=True)

# %%
data['hsc_pass_year'].replace('16', '2016',inplace=True)

# %%
data['hsc_pass_year'].replace('Diploma 2020','2020',inplace=True)

# %%
data['hsc_pass_year'].replace('Diploma (2021)','2021',inplace=True)

# %%
data['hsc_pass_year'].replace('Diploma  2019','2019',inplace=True)

# %%
data['hsc_pass_year'].replace('W','2017',inplace=True)

# %%
data['hsc_pass_year'].replace('Diploma-2018','2018',inplace=True)

# %%
pd.value_counts(data['hsc_pass_year'])
# Out:
# 2020                                       294
# 2019                                       165
# 2018                                        95
# 2017                                        45
# 2016                                        23
# 2021                                        15
# 2014                                        10
# 2015                                         6
# 2013                                         2
# 2022                                         2
# Diploma 2018                                 1
# 2017(Diploma in Engineering)                 1
# 2020 (Diploma)                               1
# Completed Diploma ( 2021)                    1
# 2028                                         1
# 2019-2020 batch passing year 2021            1
# 2017 (DIPLOMA)                               1
# 2018(diploma)                                1
# Diloma 2020                                  1
# Diploma passed                               1
# ...

# %%
data['hsc_pass_year'].replace('Diploma in Engineer passing year:  2020','2020',inplace=True)

# %%
pd.value_counts(data['hsc_pass_year'])
# Out:
# 2020                                 295
# 2019                                 165
# 2018                                  95
# 2017                                  45
# 2016                                  23
# 2021                                  15
# 2014                                  10
# 2015                                   6
# 2013                                   2
# 2022                                   2
# Diploma 2018                           1
# 2020 (Diploma)                         1
# 2017(Diploma in Engineering)           1
# Completed Diploma ( 2021)              1
# 2028                                   1
# 2019-2020 batch passing year 2021      1
# 2018(diploma)                          1
# 20                                     1
# Diploma passed                         1
# 18                                     1
# Diloma 2020                            1
# 2012                                   1
# 17                                     1
# ...

# %%
data['hsc_pass_year'].replace('Diploma 2018','2018',inplace=True)

# %%
data['hsc_pass_year'].replace(' ','',inplace=True)

# %%
pd.value_counts(data['hsc_pass_year'])
# Out:
# 2020                                 295
# 2019                                 165
# 2018                                  96
# 2017                                  45
# 2016                                  23
# 2021                                  15
# 2014                                  10
# 2015                                   6
# 2013                                   2
# 2022                                   2
# 2018(diploma)                          1
# 2020 (Diploma)                         1
# 2017(Diploma in Engineering)           1
# Completed Diploma ( 2021)              1
# Diploma passed                         1
# 2019-2020 batch passing year 2021      1
# 2028                                   1
# 20                                     1
# 18                                     1
# Diloma 2020                            1
# 2012                                   1
# 17                                     1
# 19                                     1
# ...

# %%
data['hsc_pass_year'].replace('2017 (DIPLOMA)','2017',inplace=True)

# %%
pd.value_counts(data['hsc_pass_year'])
# Out:
# 2020                                 295
# 2019                                 165
# 2018                                  96
# 2017                                  46
# 2016                                  23
# 2021                                  15
# 2014                                  10
# 2015                                   6
# 2013                                   2
# 2022                                   2
# Diploma passed                         1
# 2019-2020 batch passing year 2021      1
# 2020 (Diploma)                         1
# Completed Diploma ( 2021)              1
# 2017(Diploma in Engineering)           1
# 2018(diploma)                          1
# 2028                                   1
# Diploma degree 2020                    1
# 19                                     1
# Diloma 2020                            1
# 20                                     1
# Diploma degree                         1
# 2012                                   1
# ...

# %%
data['hsc_pass_year'].replace('17','2017',inplace=True)

# %%
pd.value_counts(data['hsc_pass_year'])
# Out:
# 2020                                 295
# 2019                                 165
# 2018                                  96
# 2017                                  47
# 2016                                  23
# 2021                                  15
# 2014                                  10
# 2015                                   6
# 2022                                   2
# 2013                                   2
# 2012                                   1
# 19                                     1
# Diploma degree 2020                    1
# Diloma 2020                            1
# Diploma degree                         1
# 18                                     1
# Diploma passed                         1
# 2028                                   1
# 2018(diploma)                          1
# 2017(Diploma in Engineering)           1
# Completed Diploma ( 2021)              1
# 2020 (Diploma)                         1
# 2019-2020 batch passing year 2021      1
# ...

# %%
data['hsc_pass_year'].replace('19','2019',inplace=True)
data['hsc_pass_year'].replace('Diploma degree 2020','2020',inplace=True)
data['hsc_pass_year'].replace('Diloma 2020','2020',inplace=True)
data['hsc_pass_year'].replace('Diploma degree ','2020',inplace=True)
data['hsc_pass_year'].replace('18','2018',inplace=True)
data['hsc_pass_year'].replace('Diploma passed ','2020',inplace=True)
data['hsc_pass_year'].replace('2028','2020',inplace=True)
data['hsc_pass_year'].replace('2018(diploma)','2018',inplace=True)
data['hsc_pass_year'].replace('2017(Diploma in Engineering)','2017',inplace=True)
data['hsc_pass_year'].replace('Completed Diploma ( 2021)','2021',inplace=True)
data['hsc_pass_year'].replace('2020 (Diploma)','2020',inplace=True)
data['hsc_pass_year'].replace('2019-2020 batch passing year 2021','2021',inplace=True)
data['hsc_pass_year'].replace('20','2020',inplace=True)

# %%
pd.value_counts(data['hsc_pass_year'])
# Out:
# 2020    302
# 2019    166
# 2018     98
# 2017     48
# 2016     23
# 2021     17
# 2014     10
# 2015      6
# 2022      2
# 2013      2
# 2012      1
# Name: hsc_pass_year, dtype: int64

# %%
#convert all the year into integer type
data['hsc_pass_year']=data['hsc_pass_year'].astype(int)

# %% [markdown]
# #create fucntion to see the difference of hsc passing year and admision year
#
# def admsn_diff(hsc,adms):
#     if(adms>hsc):
#         diff = int(adms)-int(hsc)
#         return diff
#     else:
#         return '0'
# #creating new column based on condition
# data['admission_diff']=data['uni_admssn_year'].apply(admsn_diff('hsc_pass_year','uni_admssn_year'))

# %% [markdown]
# ##### feature engineering for uni_admssn_year

# %%
pd.value_counts(data['uni_admssn_year'])
# Out:
# 2022              215
# 2021              182
# 2020              114
# 2019               96
# 2018               32
# 2017               11
# 2015                5
# 2016                4
# 2014                2
# 2021 Fall           1
# December 2019.      1
# 2020 (summer)       1
# Spring 2022         1
# 20208               1
# fall 2020           1
# 19                  1
# fall 2021           1
# 21                  1
# Spri                1
# 3rd year            1
# 18                  1
# 22                  1
# 17                  1
# Name: uni_admssn_year, dtype: int64

# %%
data['uni_admssn_year'].replace('17','2017',inplace=True)
data['uni_admssn_year'].replace('2021 Fall','2021',inplace=True)
data['uni_admssn_year'].replace('December 2019.','2019',inplace=True)
data['uni_admssn_year'].replace('2020 (summer)','2020',inplace=True)
data['uni_admssn_year'].replace('Spring 2022','2022',inplace=True)
data['uni_admssn_year'].replace('20208','2020',inplace=True)
data['uni_admssn_year'].replace('fall 2020','2020',inplace=True)
data['uni_admssn_year'].replace('19','2019',inplace=True)
data['uni_admssn_year'].replace('fall 2021','2021',inplace=True)
data['uni_admssn_year'].replace('21','2021',inplace=True)
data['uni_admssn_year'].replace('Spri','2021',inplace=True)
data['uni_admssn_year'].replace('3rd year','2021',inplace=True)
data['uni_admssn_year'].replace('18','2018',inplace=True)
data['uni_admssn_year'].replace('22','2022',inplace=True)
data['uni_admssn_year'].replace('17','2017',inplace=True)

# %%
pd.value_counts(data['uni_admssn_year'])
# Out:
# 2022    217
# 2021    187
# 2020    117
# 2019     98
# 2018     33
# 2017     12
# 2015      5
# 2016      4
# 2014      2
# Name: uni_admssn_year, dtype: int64

# %%
data['uni_admssn_year']=data['uni_admssn_year'].astype(int)

# %% [markdown]
# #create fucntion to see the difference of hsc passing year and admision year
#
# def admsn_diff(hsc,adms):
#     if(adms>hsc):
#         diff = adms - hsc
#         return diff
#     else:
#         diff=0
#         return diff
# #creating new column based on condition
# data['admission_diff']=data.apply(admsn_diff(data['hsc_pass_year'],data['uni_admssn_year']))

# %%
#make new column for see the difference between admission year and hsc year

condition = [data['uni_admssn_year']>data['hsc_pass_year']]

output = [data['uni_admssn_year']-data['hsc_pass_year']]

#df['salary_age_relation'] = np.select(conditions, outputs, 'no salary')

data['admission_diff']=np.select(condition,output,0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    object
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    object
#  10  use_uni_transport    675 non-null    object
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    object
#  14  have_smart_device    675 non-null    object
# ...

# %%
pd.value_counts(data['admission_diff'])
# Out:
# 2    290
# 1    287
# 0     44
# 3     40
# 4      7
# 5      3
# 7      3
# 6      1
# Name: admission_diff, dtype: int64

# %%
#see which students have 6 years differencce

data.loc[data['admission_diff']==7,['name','id','cgpa','uni_admssn_year','hsc_pass_year']]
# Out:
#              name        id  cgpa  uni_admssn_year  hsc_pass_year
# 389    Shovon Roy  22103117   2.1             2022           2015
# 494  Lamia Hoque   21303177  3.36             2021           2014
# 537  Lamia Hoque   21303177  3.38             2021           2014

# %%
data.head()
# Out:
#          id                      name  gender age  hsc_pass_year  \
# 0  18303059                Abu Raihan    Male  24           2016
# 1  21203066       Jahidul Islam Anik     Male  22           2020
# 2  20103005  Symu Alahi Jannat Abonti  Female  21           2019
# 3  21203080     Hedayetul Islam Anik     Male  20           2020
# 4  21203032           Abu Aslam Mithu    Male  22           2019
#
#    uni_admssn_year uni_name program  curr_sem merit_scholarship  ...  \
# 0             2018    IUBAT    BCSE        12               Yes  ...
# 1             2021   IUBAT     BCSE         4               Yes  ...
# 2             2020    IUBAT    BCSE         5                No  ...
# 3             2021    IUBAT    BCSE         4               Yes  ...
# 4             2021    IUBAT    BCSE         4               Yes  ...
#
#   team_task  phy_disb                         family_inc family_mem self_dep  \
# 0       Yes        No                              25000          6       No
# ...

# %%
data['admission_diff']
# Out:
# 0      2
# 1      1
# 2      1
# 3      1
# 4      2
#       ..
# 670    2
# 671    2
# 672    1
# 673    1
# 674    1
# Name: admission_diff, Length: 675, dtype: int32

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    object
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    object
#  10  use_uni_transport    675 non-null    object
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    object
#  14  have_smart_device    675 non-null    object
# ...

# %% [markdown]
# ##### Feature engineering for Current Semester

# %%
data['curr_sem'].unique()
# Out:
# array([12,  4,  5,  1,  2, 11,  8, 10,  9, 13, 15, 14,  6,  7, 18, 17,  3,
#        21, 22], dtype=int64)

# %%
pd.value_counts(data['curr_sem'])
# Out:
# 2     211
# 8      99
# 3      88
# 11     56
# 4      54
# 1      48
# 9      24
# 7      17
# 5      17
# 12     15
# 10     11
# 14     10
# 6       9
# 13      6
# 15      5
# 17      2
# 18      1
# 21      1
# 22      1
# Name: curr_sem, dtype: int64

# %%
#see which students are in which semester

data.loc[data['curr_sem']==14,['name','id','cgpa','uni_admssn_year']]
# Out:
#                       name        id  cgpa  uni_admssn_year
# 121        Kawser Hossain   18103210  2.99             2018
# 129     Fatema Tuz Zohora   18103360  2.96             2018
# 138           Md.Tareq Mia  18103045  2.68             2018
# 190      Khadizatul Mishu   18103189   3.2             2018
# 206       Md. Abdul khalak  18103196   2.8             2018
# 252  Mst.Sonia Akhter Moon  17203055  2.84             2017
# 298      Afroja Nahar Akhi  18103354  2.95             2018
# 402          Israth jarin   18103167  2.56             2018
# 578         Samim Al Masud  18103193  3.06             2018
# 600             Eshrat Ara  18103276  2.88             2018

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    object
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    object
#  10  use_uni_transport    675 non-null    object
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    object
#  14  have_smart_device    675 non-null    object
# ...

# %% [markdown]
# ##### Feature engineering for mirit scholarship

# %%
data['merit_scholarship'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
pd.value_counts(data['merit_scholarship'])
# Out:
# Yes    393
# No     282
# Name: merit_scholarship, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    object
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    object
#  10  use_uni_transport    675 non-null    object
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    object
#  14  have_smart_device    675 non-null    object
# ...

# %% [markdown]
# ##### Feature engineering for use_uni_transport

# %%
data['use_uni_transport'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
pd.value_counts(data['use_uni_transport'])
# Out:
# No     346
# Yes    329
# Name: use_uni_transport, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    object
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    object
#  10  use_uni_transport    675 non-null    object
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    object
#  14  have_smart_device    675 non-null    object
# ...

# %% [markdown]
# ##### Feature engineering for study_hour/day

# %%
data['study_hour/day'].unique()
# Out:
# array([ 3,  1,  4,  2,  5,  6,  8,  7,  0,  9, 30, 10], dtype=int64)

# %%
pd.value_counts(data['study_hour/day'])
# Out:
# 3     192
# 2     147
# 4     123
# 5      73
# 1      64
# 6      42
# 7      13
# 0      10
# 8       7
# 9       2
# 30      1
# 10      1
# Name: study_hour/day, dtype: int64

# %%
#see which students study 30 hour

data.loc[data['study_hour/day']==10,['name','id','cgpa','uni_admssn_year']]
# Out:
#                name        id  cgpa  uni_admssn_year
# 582  Nur Alam Rimon  21203008  2.47             2021

# %%
data['study_hour/day'].replace(30,3,inplace=True)

# %%
data['study_hour/day'].replace(10,1,inplace=True)

# %%
pd.value_counts(data['study_hour/day'])
# Out:
# 3    193
# 2    147
# 4    123
# 5     73
# 1     65
# 6     42
# 7     13
# 0     10
# 8      7
# 9      2
# Name: study_hour/day, dtype: int64

# %% [markdown]
# ##### feature engineering for freq_study/day

# %%
data['freq_study/day'].unique()
# Out:
# array([ 2,  3,  1,  4,  5,  6,  8,  0, 10,  7], dtype=int64)

# %%
pd.value_counts(data['freq_study/day'])
# Out:
# 2     278
# 1     185
# 3     156
# 4      28
# 5      12
# 0       6
# 6       5
# 8       3
# 10      1
# 7       1
# Name: freq_study/day, dtype: int64

# %%
#see which students study 10 times a day

data.loc[data['freq_study/day']==7,['name','id','cgpa','uni_admssn_year']]
# Out:
#                     name        id  cgpa  uni_admssn_year
# 666  Mst. Jamiya Akther   21303190  1.64             2021

# %%
data['freq_study/day'].replace(10,1,inplace=True)
data['freq_study/day'].replace(7,1,inplace=True)
data['freq_study/day'].replace(8,1,inplace=True)

# %%
pd.value_counts(data['freq_study/day'])
# Out:
# 2    278
# 1    190
# 3    156
# 4     28
# 5     12
# 0      6
# 6      5
# Name: freq_study/day, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    object
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    object
#  10  use_uni_transport    675 non-null    object
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    object
#  14  have_smart_device    675 non-null    object
# ...

# %%
#engineering for learning mode
pd.value_counts(data['learning_mode'])
# Out:
# Offline    493
# Online     182
# Name: learning_mode, dtype: int64

# %%
#engineering for smart device
pd.value_counts(data['have_smart_device'])
# Out:
# Yes    661
# No      14
# Name: have_smart_device, dtype: int64

# %%
#engineering for having personal computer
pd.value_counts(data['have_pc'])
# Out:
# Yes    618
# No      57
# Name: have_pc, dtype: int64

# %%
#engineering for social media time spent
pd.value_counts(data['social_media_time'])
# Out:
# 2     203
# 3     174
# 1     114
# 4      75
# 5      43
# 6      28
# 7      11
# 8       8
# 0       6
# 10      5
# 12      4
# 15      3
# 16      1
# Name: social_media_time, dtype: int64

# %%
data['social_media_time'].unique()
# Out:
# array([ 5,  3,  2,  1,  4,  6,  0,  7,  8, 15, 10, 12, 16], dtype=int64)

# %%
#scaling all values above 10 into 8
data['social_media_time'].replace(16,8,inplace=True)
data['social_media_time'].replace(15,8,inplace=True)
data['social_media_time'].replace(12,8,inplace=True)
data['social_media_time'].replace(10,8,inplace=True)

# %%
pd.value_counts(data['social_media_time'])
# Out:
# 2    203
# 3    174
# 1    114
# 4     75
# 5     43
# 6     28
# 8     21
# 7     11
# 0      6
# Name: social_media_time, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    object
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    object
#  10  use_uni_transport    675 non-null    object
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    object
#  14  have_smart_device    675 non-null    object
# ...

# %%
#engineering for english_skill
pd.value_counts(data['english_skill'])
# Out:
# Intermediate    397
# Basic           213
# Advance          65
# Name: english_skill, dtype: int64

# %%
#engineering for Attendance
pd.value_counts(data['attendance'])
# Out:
# 100%           108
# 90%            102
# 95%             77
# 90              54
# 80%             54
# 98%             35
# 99%             33
# 100             32
# 70%             27
# 85%             18
# 80              18
# 97%             17
# 95              16
# 98              11
# 99               9
# 85               8
# 50%              7
# 97               4
# 60%              4
# 96%              4
# 75               3
# 60               3
# 70               3
# 75%              2
# 99.00%           2
# 92%              1
# 88               1
# 95%+             1
# 10%              1
# 2%               1
# 93%              1
# 88%              1
# 78%              1
# 92               1
# 37               1
# 87%              1
# 65%              1
# 90.00%           1
# 5%               1
# 40%              1
# 70 percent       1
# 25               1
# 96               1
# 80-90%           1
# Above 95%        1
# 98-100%          1
# 70/80%           1
# ...

# %%
data['attendance'].replace(600,'less_50',inplace=True)

# %%
data['attendance'].replace('100%',100,inplace=True)
data['attendance'].replace('100',100,inplace=True)
data['attendance'].replace('90',90,inplace=True)
data['attendance'].replace('57',60,inplace=True)
data['attendance'].replace('Above 85%',85,inplace=True)
data['attendance'].replace('70/80%',80,inplace=True)
data['attendance'].replace('98-100%',98,inplace=True)
data['attendance'].replace('Above 95%',95,inplace=True)
data['attendance'].replace('80-90%',90,inplace=True)
data['attendance'].replace('80-90%',90,inplace=True)

# %%
data['attendance'].replace('97%',97,inplace=True)

# %%
pd.value_counts(data['attendance'])
# Out:
# 100            140
# 90%            102
# 95%             77
# 90              55
# 80%             54
# 98%             35
# 99%             33
# 70%             27
# 80              18
# 85%             18
# 97              17
# 95              16
# 98              11
# 99               9
# 85               8
# 50%              7
# 96%              4
# 97               4
# 60%              4
# 60               3
# 70               3
# 75               3
# 75%              2
# 99.00%           2
# 2%               1
# 37               1
# 88               1
# 93%              1
# 92%              1
# 88%              1
# 78%              1
# 92               1
# 10%              1
# 90.00%           1
# 65%              1
# 85               1
# 5%               1
# 40%              1
# 87%              1
# 25               1
# 96               1
# 95%+             1
# 95               1
# 98               1
# 70 percent       1
# 80               1
# 60               1
# ...

# %%
data['attendance'].replace('70 percent ',70,inplace=True)
data['attendance'].replace('95%+',95,inplace=True)
data['attendance'].replace('87%',87,inplace=True)
data['attendance'].replace('40%',40,inplace=True)
data['attendance'].replace('5%','bellow_50',inplace=True)
data['attendance'].replace('65%',65,inplace=True)
data['attendance'].replace('90.00%',90,inplace=True)
data['attendance'].replace('10%','bellow_50',inplace=True)
data['attendance'].replace('78%',78,inplace=True)
data['attendance'].replace('88%',88,inplace=True)
data['attendance'].replace('92%',92,inplace=True)
data['attendance'].replace('93%',93,inplace=True)
data['attendance'].replace('2%','bellow_50',inplace=True)
data['attendance'].replace('99.00%',99,inplace=True)
data['attendance'].replace('75%',75,inplace=True)
data['attendance'].replace('60%',60,inplace=True)
data['attendance'].replace('96%',96,inplace=True)
data['attendance'].replace('85%',85,inplace=True)
data['attendance'].replace('98%',98,inplace=True)
data['attendance'].replace('70%',70,inplace=True)
data['attendance'].replace('80%',80,inplace=True)
data['attendance'].replace('99 ',99,inplace=True)
data['attendance'].replace('95%',95,inplace=True)
data['attendance'].replace('90%',90,inplace=True)
data['attendance'].replace('50%',50,inplace=True)
data['attendance'].replace('96',96,inplace=True)
data['attendance'].replace('95',95,inplace=True)
data['attendance'].replace('99',99,inplace=True)

# %%
pd.value_counts(data['attendance'])
# Out:
# 90           158
# 100          140
# 95            95
# 80            55
# 98            36
# 99%           33
# 70            28
# 85            19
# 80            18
# 97            17
# 99            11
# 98            11
# 85             8
# 50             7
# 60             5
# 96             5
# 97             4
# bellow_50      3
# 60             3
# 75             3
# 70             3
# 75             2
# 40             1
# 87             1
# 65             1
# 25             1
# 92             1
# 88             1
# 37             1
# 93             1
# 88             1
# 78             1
# 92             1
# Name: attendance, dtype: int64

# %%
data['attendance'].unique()
# Out:
# array([90, 96, '80', '85', 95, 100, 97, 70, 80, 98, 85, '97', '99%', '70',
#        99, 50, '75', '25', 87, 40, 'bellow_50', '60', 65, '98', 60, 92,
#        75, '88', '37', 93, 88, 78, '92'], dtype=object)

# %%
data['attendance'].replace('98',98,inplace=True)
data['attendance'].replace('80',80,inplace=True)
data['attendance'].replace('85',85,inplace=True)
data['attendance'].replace('88',88,inplace=True)
data['attendance'].replace('25','bellow_50',inplace=True)
data['attendance'].replace('97',97,inplace=True)
data['attendance'].replace('70',70,inplace=True)
data['attendance'].replace('75',75,inplace=True)
data['attendance'].replace(40,'bellow_50',inplace=True)
data['attendance'].replace('37','bellow_50',inplace=True)
data['attendance'].replace('92',92,inplace=True)
data['attendance'].replace('60',60,inplace=True)
data['attendance'].replace('99%',99,inplace=True)

# %%
pd.value_counts(data['attendance'])
# Out:
# 90           158
# 100          140
# 95            95
# 80            73
# 98            47
# 60            41
# 70            31
# 85            27
# 97            21
# 99            11
# 50             7
# bellow_50      6
# 96             5
# 75             5
# 92             2
# 88             2
# 87             1
# 65             1
# 93             1
# 78             1
# Name: attendance, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 40 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    object
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    object
#  10  use_uni_transport    675 non-null    object
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    object
#  14  have_smart_device    675 non-null    object
# ...

# %%
#engineering for probation
pd.value_counts(data['probation'])
# Out:
# No     541
# Yes    134
# Name: probation, dtype: int64

# %%
#engineering for suspension
pd.value_counts(data['suspension'])
# Out:
# No     651
# Yes     24
# Name: suspension, dtype: int64

# %%
#engineering for faculty consultency
pd.value_counts(data['faculty_consultency'])
# Out:
# Yes    421
# No     254
# Name: faculty_consultency, dtype: int64

# %%
#engineering for skill and time on skill development
data.drop(['skills'],axis=1,inplace=True)
data.drop(['skill_dev_hour'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 38 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    object
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    object
#  10  use_uni_transport    675 non-null    object
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    object
#  14  have_smart_device    675 non-null    object
# ...

# %%
#engineering for relationship status
pd.value_counts(data['relation_sts'])
# Out:
# Single               592
# In a relationship     39
# Married               29
# Engaged               15
# Name: relation_sts, dtype: int64

# %%
#engineering for curriculumn activities
pd.value_counts(data['curri_act'])
# Out:
# No     410
# Yes    265
# Name: curri_act, dtype: int64

# %%
#engineering for living status
pd.value_counts(data['living_sts'])
# Out:
# Family      375
# Bachelor    300
# Name: living_sts, dtype: int64

# %%
#engineering for kids
pd.value_counts(data['kids'])
# Out:
# No     667
# Yes      8
# Name: kids, dtype: int64

# %%
#see which students have kids

data.loc[data['kids']=='Yes',['name','id','cgpa','uni_admssn_year']]
# Out:
#                             name        id  cgpa  uni_admssn_year
# 77                 Chadni Akter   22103085   NaN             2022
# 131          FahmidaHoqueNisa     22103061   NaN             2021
# 148     Mst.Rubayat yesmin Rumi   17203064   NaN             2017
# 276  Rubaya Tul Mubashara Sumaya  15303030  2.89             2015
# 494                 Lamia Hoque   21303177  3.36             2021
# 537                 Lamia Hoque   21303177  3.38             2021
# 576       Mahmuda Yeasmin Mukti   17103285  3.44             2017
# 620         Rajwana Shahin Seema  22103174  2.86             2021

# %%
#engineering for political engagement 
pd.value_counts(data['political_eng'])
# Out:
# No     651
# Yes     24
# Name: political_eng, dtype: int64

# %%
#engineering for phy_issue
pd.value_counts(data['phy_issue'])
# Out:
# No     546
# Yes    129
# Name: phy_issue, dtype: int64

# %%
#engineering for team_task
pd.value_counts(data['team_task'])
# Out:
# Yes    463
# No     212
# Name: team_task, dtype: int64

# %%
#engineering for phy_disb
pd.value_counts(data['phy_disb'])
# Out:
# No     656
# Yes     19
# Name: phy_disb, dtype: int64

# %%
#drop family income column
data.drop(['family_inc'],axis=1,inplace=True)

# %%
#drop family member column
data.drop(['family_mem'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    object
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    object
#  10  use_uni_transport    675 non-null    object
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    object
#  14  have_smart_device    675 non-null    object
# ...

# %%
#engineering for hometown
#drop family member column
data.drop(['hometown'],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 35 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    object
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    object
#  10  use_uni_transport    675 non-null    object
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    object
#  14  have_smart_device    675 non-null    object
# ...

# %%
pd.value_counts(data['self_dep'])
# Out:
# 0    384
# 2    199
# 1     92
# Name: self_dep, dtype: int64

# %% [markdown]
# # Adding new Data Frame

# %%
#data.to_csv('upto_feature_engineering.csv')

# %%
df3 = pd.read_csv('cgpa_sgpa (2).csv', encoding= 'unicode_escape')
#data = pd.read_csv(filename, encoding= 'unicode_escape')

# %%
df3.head()
# Out:
#    sgpa   cgpa  comp_cred      hometown
# 0  2.04   3.41        136       Tangail
# 1  2.51   2.91         35  Narayanganj
# 2  3.10   3.26         41       Rangpur
# 3  3.56   3.34         35    Madaripur
# 4  2.31   2.60         35       Rangpur

# %%
df3=df3.rename(columns={'sgpa':'pre_sgpa','cgpa':'cgpa','hometown':'hometown'},inplace=False)

# %%
#df1.loc[df1['sgpa']=="NaN"].replace("NaN",0,inplace=True)

# %%
df3.head()
# Out:
#    pre_sgpa   cgpa  comp_cred      hometown
# 0      2.04   3.41        136       Tangail
# 1      2.51   2.91         35  Narayanganj
# 2      3.10   3.26         41       Rangpur
# 3      3.56   3.34         35    Madaripur
# 4      2.31   2.60         35       Rangpur

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pre_sgpa   675 non-null    float64
#  1   cgpa       675 non-null    object
#  2   comp_cred  675 non-null    int64
#  3   hometown   675 non-null    object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 21.2+ KB

# %%
df3['cgpa'].unique()
# Out:
# array(['3.41', '2.91', 3.26, '3.34', '2.60', '3.13', '3.42', '3.64',
#        '2.72', '3.97', '3.94', '3.53', '3.49', '2.86', '3.89', '3.83',
#        '2.95', '3.50', '3.43', '3.65', '2.66', '3.58', '3.98', '3.81',
#        '3.82', '2.89', '3.48', '3.32', '3.79', '4.00', '3.59', '3.95',
#        '3.46', '1.85', '2.94', '3.84', '3.75', '3.73', '3.88', '2.88',
#        '3.56', '3.51', '3.90', '3.86', '2.83', '3.67', '3.80', '2.98',
#        '3.52', '3.74', '3.78', '2.78', '3.70', '3.08', '3.35', '3.77',
#        '2.74', '3.54', '2.80', '3.63', '3.11', '2.82', '3.10', '2.77',
#        '3.72', '2.93', '3.17', '2.63', '2.69', '3.02', '2.96', '2.51',
#        '2.53', '2.99', '3.12', '2.39', '3.16', '2.92', '2.62', '2.90',
#        '3.01', '3.29', '2.68', '2.42', '3.55', '2.21', '2.49', '3.37',
#        '3.23', '2.22', '3.62', '3.24', '2.56', '2.76', '3.30', '2.40',
#        '2.75', '3.22', '2.48', '2.31', '3.20', '2.73', '3.19', '0.00',
# ...

# %%
df3['cgpa'].replace('2. 81',2.81,inplace=True)

# %%
df3['cgpa'].replace('\xa03.26',3.26,inplace=True)

# %%
#converting cgpa column from obejct type to float type
df3['cgpa']=df3['cgpa'].apply(pd.to_numeric)

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pre_sgpa   675 non-null    float64
#  1   cgpa       675 non-null    float64
#  2   comp_cred  675 non-null    int64
#  3   hometown   675 non-null    object
# dtypes: float64(2), int64(1), object(1)
# memory usage: 21.2+ KB

# %%
#converting sgpa column from obejct type to float type
df3['pre_sgpa']=df3['pre_sgpa'].apply(pd.to_numeric)

# %%
df3.head()
# Out:
#    pre_sgpa  cgpa  comp_cred      hometown
# 0      2.04  3.41        136       Tangail
# 1      2.51  2.91         35  Narayanganj
# 2      3.10  3.26         41       Rangpur
# 3      3.56  3.34         35    Madaripur
# 4      2.31  2.60         35       Rangpur

# %%
#saving the dataframe
df3.to_csv('sgpa_cgpa_com_cred_hometown.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    int64
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    int64
#  10  use_uni_transport    675 non-null    int64
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    int64
#  14  have_smart_device    675 non-null    int64
# ...

# %%
#drop column of main dataframe
data.drop(["pre_sgpa"],axis=1,inplace=True)
data.drop(["cgpa"],axis=1,inplace=True)
data.drop(["comp_cred"],axis=1,inplace=True)
data.drop(["hometown"],axis=1,inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 33 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    int64
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    int64
#  10  use_uni_transport    675 non-null    int64
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    int64
#  14  have_smart_device    675 non-null    int64
# ...

# %%
#adding column in main data frame from new dataframe
data['pre_sgpa']=df3['pre_sgpa']
data['cgpa']=df3['cgpa']
data['comp_cred']=df3['comp_cred']
data['hometown']=df3['hometown']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    int64
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    int64
#  10  use_uni_transport    675 non-null    int64
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    int64
#  14  have_smart_device    675 non-null    int64
# ...

# %%
data.head(100)
# Out:
#           id                      name  gender age  hsc_pass_year  \
# 0   18303059                Abu Raihan       1  24           2016
# 1   21203066       Jahidul Islam Anik        1  22           2020
# 2   20103005  Symu Alahi Jannat Abonti       0  21           2019
# 3   21203080     Hedayetul Islam Anik        1  20           2020
# 4   21203032           Abu Aslam Mithu       1  22           2019
# ..       ...                       ...     ...  ..            ...
# 95  22103037     Sumaiya Akter Badhon        0  21           2020
# 96  22103070             Golam Robbani       1  20           2020
# 97  21203033         Abdullah Al Mamun       1  22           2020
# 98  21103032           Md Mehedi Hasan       1  20           2019
# 99  19103118             Imtiaz Tasnim       1  23           2017
#
#     uni_admssn_year                                           uni_name  \
# 0              2018                                              IUBAT
# ...

# %%
#make a masking dataframe of main dataframe that main data frame may not affect any break

mdf = data

# %%
mdf.head()
# Out:
#          id                      name  gender age  hsc_pass_year  \
# 0  18303059                Abu Raihan       1  24           2016
# 1  21203066       Jahidul Islam Anik        1  22           2020
# 2  20103005  Symu Alahi Jannat Abonti       0  21           2019
# 3  21203080     Hedayetul Islam Anik        1  20           2020
# 4  21203032           Abu Aslam Mithu       1  22           2019
#
#    uni_admssn_year uni_name program  curr_sem  merit_scholarship  ...  \
# 0             2018    IUBAT    BCSE        12                  1  ...
# 1             2021   IUBAT     BCSE         4                  1  ...
# 2             2020    IUBAT    BCSE         5                  0  ...
# 3             2021    IUBAT    BCSE         4                  1  ...
# 4             2021    IUBAT    BCSE         4                  1  ...
#
#    phy_issue  team_task  phy_disb  self_dep  admission_diff  Student_status  \
# ...

# %%
pd.value_counts(mdf['faculty_consultency'])
# Out:
# 1    421
# 0    254
# Name: faculty_consultency, dtype: int64

# %% [markdown]
# ## Creating target column based on x columns

# %%
mdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    int64
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    int64
#  10  use_uni_transport    675 non-null    int64
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    int64
#  14  have_smart_device    675 non-null    int64
# ...

# %%
mdf.to_csv("upto_cond1.csv")

# %%
mdf['attendance'].dtypes
# Out:
# dtype('int64')

# %%
pd.value_counts(mdf['attendance'])
# Out:
# 90     158
# 100    140
# 95      95
# 80      73
# 98      47
# 60      41
# 70      31
# 85      27
# 97      21
# 50      13
# 99      11
# 96       5
# 75       5
# 92       2
# 88       2
# 87       1
# 65       1
# 93       1
# 78       1
# Name: attendance, dtype: int64

# %%
#replacing bellow 50% attebdance into 50
mdf['attendance'].replace('bellow_50',50,inplace=True)

# %%
pd.value_counts(mdf['attendance'])
# Out:
# 90     158
# 100    140
# 95      95
# 80      73
# 98      47
# 60      41
# 70      31
# 85      27
# 97      21
# 50      13
# 99      11
# 96       5
# 75       5
# 92       2
# 88       2
# 87       1
# 65       1
# 93       1
# 78       1
# Name: attendance, dtype: int64

# %% [markdown]
# #### Targeted column value will be -
# 1. Excellent (if cgpa>3.75)
# 2. Good (if 3.8>cgpa>3.5)
# 3. Average (if 3<cgpa<3.5)
# 4. Poor (if 2.5<cgpa<3)
# 5. probation (if cgpa < 2.5)

# %%
#make a targeted column based on other column condition


condition = [(mdf['study_hour/day']>=3) & (mdf['cgpa']>=3.75) & (mdf['pre_sgpa']>=3.20) 
             & ((mdf['english_skill']== 1)|(mdf['english_skill']== 2) | (mdf['english_skill']== 0)) 
             & (mdf['attendance']>=90) & (mdf['social_media_time']<=3),
             
             
(mdf['study_hour/day']>=2) & ((mdf['cgpa']>= 3.20) | (mdf['pre_sgpa']>=2.90))
             & ((mdf['english_skill']== 1)|(mdf['english_skill']== 0) | (mdf['english_skill']== 2))
             & (mdf['attendance']>=85)& (mdf['social_media_time']<=4),

(mdf['study_hour/day']>=1) & ((mdf['cgpa']>= 2.80) | (mdf['pre_sgpa']>=2.50))
             & ((mdf['english_skill']== 1)|(mdf['english_skill']== 0) | (mdf['english_skill']== 2))
             & (mdf['attendance']>=75) & (mdf['social_media_time']<=5),
            
             
(mdf['study_hour/day']>=1) & (mdf['cgpa']>= 2.50) | (mdf['pre_sgpa']>=2.50)
             & ((mdf['english_skill']== 1)|(mdf['english_skill']== 0)| (mdf['english_skill']== 2)) 
             & (mdf['attendance']>=50) & (mdf['social_media_time']<=6)
            
            
            ]
                                                                                               


output = ['Excellent','Good','Average','Poor']

#df['salary_age_relation'] = np.select(conditions, outputs, 'no salary')

data['Student_status']=np.select(condition,output,'Probation')

# %%
mdf['Student_status'].unique()
# Out:
# array(['Average', 'Poor', 'Good', 'Excellent', 'Probation'], dtype=object)

# %%
pd.value_counts(mdf['english_skill'])
# Out:
# 1    397
# 0    213
# 2     65
# Name: english_skill, dtype: int64

# %%
pd.value_counts(mdf['faculty_consultency'])
# Out:
# 1    421
# 0    254
# Name: faculty_consultency, dtype: int64

# %%
pd.value_counts(mdf['Student_status'])
# Out:
# Good         269
# Average      147
# Poor         137
# Probation     72
# Excellent     50
# Name: Student_status, dtype: int64

# %%
#see which students performance is Ecellent

mdf.loc[mdf['Student_status']=='Average',['name','id','cgpa','pre_sgpa','english_skill']]
# Out:
#                          name        id  cgpa  pre_sgpa  english_skill
# 0                  Abu Raihan  18303059  3.41      2.04              1
# 1         Jahidul Islam Anik   21203066  2.91      2.51              0
# 2    Symu Alahi Jannat Abonti  20103005  3.26      3.10              1
# 3       Hedayetul Islam Anik   21203080  3.34      3.56              1
# 6       Md Abdul Ahad Linkon   21203059  3.42      3.65              1
# ..                        ...       ...   ...       ...            ...
# 659     Samuel Rouddro Pahan   20103022  2.80      3.40              1
# 661             Khadiza Akter  20103219  3.50      3.40              1
# 662   Md. Sazzad Hosen Shibli  21303073  3.01      2.59              0
# 668                  MD.WALID  20103160  3.12      3.50              1
# 674           Mahazabin Akter  20103013  3.10      3.00              1
#
# [159 rows x 5 columns]

# %%
#see which students study 10 times a day

data.loc[data['freq_study/day']==7,['name','id','cgpa','uni_admssn_year']]

# %%
mdf.head()
# Out:
#          id                      name  gender age  hsc_pass_year  \
# 0  18303059                Abu Raihan    Male  24           2016
# 1  21203066       Jahidul Islam Anik     Male  22           2020
# 2  20103005  Symu Alahi Jannat Abonti  Female  21           2019
# 3  21203080     Hedayetul Islam Anik     Male  20           2020
# 4  21203032           Abu Aslam Mithu    Male  22           2019
#
#    uni_admssn_year uni_name program  curr_sem merit_scholarship  ...  \
# 0             2018    IUBAT    BCSE        12               Yes  ...
# 1             2021   IUBAT     BCSE         4               Yes  ...
# 2             2020    IUBAT    BCSE         5                No  ...
# 3             2021    IUBAT    BCSE         4               Yes  ...
# 4             2021    IUBAT    BCSE         4               Yes  ...
#
#   political_eng  phy_issue  team_task phy_disb self_dep admission_diff  \
# 0            No         No        Yes       No       No              2
# ...

# %%
mdf.to_csv("Dataframemdf_Before_feature_encoding.csv")

# %% [markdown]
# ## Feature Encoding

# %%
fenc = mdf

# %%
fenc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    int64
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    int64
#  10  use_uni_transport    675 non-null    int64
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    int64
#  14  have_smart_device    675 non-null    int64
# ...

# %% [markdown]
# ##### Gender

# %%
pd.value_counts(fenc['gender'])
# Out:
# 1    410
# 0    265
# Name: gender, dtype: int64

# %%
#ecoding male=1,female=0
fenc['gender'].replace('Male',1,inplace=True)
fenc['gender'].replace('Female',0,inplace=True)

# %%
pd.value_counts(fenc['gender'])
# Out:
# 1    410
# 0    265
# Name: gender, dtype: int64

# %% [markdown]
# ##### merit scholarship

# %%
pd.value_counts(fenc['merit_scholarship'])
# Out:
# Yes    393
# No     282
# Name: merit_scholarship, dtype: int64

# %%
#ecoding Yes=1, No=0
fenc['merit_scholarship'].replace('Yes',1,inplace=True)
fenc['merit_scholarship'].replace('No',0,inplace=True)

# %%
pd.value_counts(fenc['merit_scholarship'])
# Out:
# 1    393
# 0    282
# Name: merit_scholarship, dtype: int64

# %% [markdown]
# ##### use_uni_transport

# %%
pd.value_counts(fenc['use_uni_transport'])
# Out:
# No     346
# Yes    329
# Name: use_uni_transport, dtype: int64

# %%
#encoding for use_uni_transport Yes =1, No = 0
fenc['use_uni_transport'].replace('Yes',1,inplace=True)
fenc['use_uni_transport'].replace('No',0,inplace=True)

# %%
pd.value_counts(fenc['use_uni_transport'])
# Out:
# 0    346
# 1    329
# Name: use_uni_transport, dtype: int64

# %% [markdown]
# ##### learning_mode

# %%
pd.value_counts(fenc['learning_mode'])
# Out:
# Offline    493
# Online     182
# Name: learning_mode, dtype: int64

# %%
#encoding for learning_mode Offline =1, Online = 0
fenc['learning_mode'].replace('Offline',1,inplace=True)
fenc['learning_mode'].replace('Online',0,inplace=True)

# %%
pd.value_counts(fenc['learning_mode'])
# Out:
# 1    493
# 0    182
# Name: learning_mode, dtype: int64

# %% [markdown]
# ##### have_smart_device

# %%
pd.value_counts(fenc['have_smart_device'])
# Out:
# Yes    661
# No      14
# Name: have_smart_device, dtype: int64

# %%
#encoding for have_smart_devices Yes = 1, No = 0
fenc['have_smart_device'].replace('Yes',1,inplace=True)
fenc['have_smart_device'].replace('No',0,inplace=True)

# %%
pd.value_counts(fenc['have_smart_device'])
# Out:
# 1    661
# 0     14
# Name: have_smart_device, dtype: int64

# %% [markdown]
# ##### have_pc

# %%
pd.value_counts(fenc['have_pc'])
# Out:
# Yes    618
# No      57
# Name: have_pc, dtype: int64

# %%
#encoding for Have PC Yes = 1, No = 0
fenc['have_pc'].replace('Yes',1,inplace=True)
fenc['have_pc'].replace('No',0,inplace=True)

# %%
pd.value_counts(fenc['have_pc'])
# Out:
# 1    618
# 0     57
# Name: have_pc, dtype: int64

# %% [markdown]
# ##### english_skill

# %%
pd.value_counts(fenc['english_skill'])
# Out:
# Intermediate    397
# Basic           213
# Advance          65
# Name: english_skill, dtype: int64

# %%
#encoding for english skills -> Basic = 0, intermediate = 1, Advanced = 2
fenc['english_skill'].replace('Basic',0,inplace=True)
fenc['english_skill'].replace('Intermediate',1,inplace=True)
fenc['english_skill'].replace('Advance',2,inplace=True)

# %%
pd.value_counts(fenc['english_skill'])
# Out:
# 1    397
# 0    213
# 2     65
# Name: english_skill, dtype: int64

# %% [markdown]
# ##### Probation

# %%
pd.value_counts(fenc['probation'])
# Out:
# No     541
# Yes    134
# Name: probation, dtype: int64

# %%
#encoding for Probation Yes = 1, No = 0
fenc['probation'].replace('Yes',1,inplace=True)
fenc['probation'].replace('No',0,inplace=True)

# %%
pd.value_counts(fenc['probation'])
# Out:
# 0    541
# 1    134
# Name: probation, dtype: int64

# %% [markdown]
# ##### Suspension

# %%
pd.value_counts(fenc['suspension'])
# Out:
# No     651
# Yes     24
# Name: suspension, dtype: int64

# %%
#encoding for Suspension Yes = 1, No = 0
fenc['suspension'].replace('Yes',1,inplace=True)
fenc['suspension'].replace('No',0,inplace=True)

# %%
pd.value_counts(fenc['suspension'])
# Out:
# 0    651
# 1     24
# Name: suspension, dtype: int64

# %% [markdown]
# ##### faculty_consultency

# %%
pd.value_counts(fenc['faculty_consultency'])
# Out:
# Yes    421
# No     254
# Name: faculty_consultency, dtype: int64

# %%
#encoding for Faculty Consultency Yes = 1, No = 0
fenc['faculty_consultency'].replace('Yes',1,inplace=True)
fenc['faculty_consultency'].replace('No',0,inplace=True)

# %%
pd.value_counts(fenc['faculty_consultency'])
# Out:
# 1    421
# 0    254
# Name: faculty_consultency, dtype: int64

# %% [markdown]
# ##### relation_sts

# %%
pd.value_counts(fenc['relation_sts'])
# Out:
# Single               592
# In a relationship     39
# Married               29
# Engaged               15
# Name: relation_sts, dtype: int64

# %%
#encoding for Relationship Status -> Single = 0, In a relationship = 1, Engaged = 2, Married = 3
fenc['relation_sts'].replace('Single',0,inplace=True)
fenc['relation_sts'].replace('In a relationship',1,inplace=True)
fenc['relation_sts'].replace('Engaged',2,inplace=True)
fenc['relation_sts'].replace('Married',3,inplace=True)

# %%
pd.value_counts(fenc['relation_sts'])
# Out:
# 0    592
# 1     39
# 3     29
# 2     15
# Name: relation_sts, dtype: int64

# %% [markdown]
# ##### curri_act

# %%
pd.value_counts(fenc['curri_act'])
# Out:
# No     410
# Yes    265
# Name: curri_act, dtype: int64

# %%
#encoding for curriculumn activities Yes = 1, No = 0
fenc['curri_act'].replace('Yes',1,inplace=True)
fenc['curri_act'].replace('No',0,inplace=True)

# %%
pd.value_counts(fenc['curri_act'])
# Out:
# 0    410
# 1    265
# Name: curri_act, dtype: int64

# %% [markdown]
# ##### living_sts

# %%
pd.value_counts(fenc['living_sts'])
# Out:
# Family      375
# Bachelor    300
# Name: living_sts, dtype: int64

# %%
#encoding for Living Status Family = 1, Bachelor = 0
fenc['living_sts'].replace('Family',1,inplace=True)
fenc['living_sts'].replace('Bachelor',0,inplace=True)

# %%
pd.value_counts(fenc['living_sts'])
# Out:
# 1    375
# 0    300
# Name: living_sts, dtype: int64

# %% [markdown]
# ##### kids

# %%
pd.value_counts(fenc['kids'])
# Out:
# No     667
# Yes      8
# Name: kids, dtype: int64

# %%
#encoding for kids status Yes = 1, No = 0
fenc['kids'].replace('Yes',1,inplace=True)
fenc['kids'].replace('No',0,inplace=True)

# %%
pd.value_counts(fenc['kids'])
# Out:
# 0    667
# 1      8
# Name: kids, dtype: int64

# %% [markdown]
# ##### political_eng

# %%
pd.value_counts(fenc['political_eng'])
# Out:
# No     651
# Yes     24
# Name: political_eng, dtype: int64

# %%
#encoding for Political Engagement Yes = 1, No = 0
fenc['political_eng'].replace('Yes',1,inplace=True)
fenc['political_eng'].replace('No',0,inplace=True)

# %%
pd.value_counts(fenc['political_eng'])
# Out:
# 0    651
# 1     24
# Name: political_eng, dtype: int64

# %% [markdown]
# ##### phy_issue

# %%
pd.value_counts(fenc['phy_issue'])
# Out:
# No     546
# Yes    129
# Name: phy_issue, dtype: int64

# %%
#encoding for Physical Issues Yes = 1, No = 0
fenc['phy_issue'].replace('Yes',1,inplace=True)
fenc['phy_issue'].replace('No',0,inplace=True)

# %%
pd.value_counts(fenc['phy_issue'])
# Out:
# 0    546
# 1    129
# Name: phy_issue, dtype: int64

# %% [markdown]
# ##### team_task

# %%
pd.value_counts(fenc['team_task'])
# Out:
# Yes    463
# No     212
# Name: team_task, dtype: int64

# %%
#encoding for Team tassk Yes = 1, No = 0
fenc['team_task'].replace('Yes',1,inplace=True)
fenc['team_task'].replace('No',0,inplace=True)

# %%
pd.value_counts(fenc['team_task'])
# Out:
# 1    463
# 0    212
# Name: team_task, dtype: int64

# %% [markdown]
# ##### phy_disb

# %%
pd.value_counts(fenc['phy_disb'])
# Out:
# No     656
# Yes     19
# Name: phy_disb, dtype: int64

# %%
#encoding for Physical Disabilities Yes = 1, No = 0
fenc['phy_disb'].replace('Yes',1,inplace=True)
fenc['phy_disb'].replace('No',0,inplace=True)

# %%
pd.value_counts(fenc['phy_disb'])
# Out:
# 0    656
# 1     19
# Name: phy_disb, dtype: int64

# %% [markdown]
# ##### self_dep

# %%
pd.value_counts(fenc['self_dep'])
# Out:
# No                384
# semi-dependent    199
# Yes                92
# Name: self_dep, dtype: int64

# %%
#encoding for Self dependent Yes = 1, No = 0
fenc['self_dep'].replace('No',0,inplace=True)
fenc['self_dep'].replace('Yes',1,inplace=True)
fenc['self_dep'].replace('semi-dependent',2,inplace=True)

# %%
pd.value_counts(fenc['self_dep'])
# Out:
# 0    384
# 2    199
# 1     92
# Name: self_dep, dtype: int64

# %%
fenc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 36 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    int64
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    int64
#  10  use_uni_transport    675 non-null    int64
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    int64
#  14  have_smart_device    675 non-null    int64
# ...

# %% [markdown]
# ### Student_status

# %%
pd.value_counts(fenc['Student_status'])
# Out:
# 3    230
# 2    159
# 1    142
# 0     73
# 4     71
# Name: Student_status, dtype: int64

# %%
#encoding for student status -> Excellent = 4, Good = 3, Average = 2, Poor = 1, probation = 0
fenc['Student_status'].replace('Excellent',4,inplace=True)
fenc['Student_status'].replace('Good',3,inplace=True)
fenc['Student_status'].replace('Average',2,inplace=True)
fenc['Student_status'].replace('Poor',1,inplace=True)
fenc['Student_status'].replace('Probation',0,inplace=True)

# %%
pd.value_counts(fenc['Student_status'])
# Out:
# 3    230
# 2    159
# 1    142
# 0     73
# 4     71
# Name: Student_status, dtype: int64

# %% [markdown]
# <h1><center>Data Visualization<center><h1>

# %%
fenc.to_csv("Encode_feature_final.csv")

# %% [markdown]
# ## Checking Co-relation

# %%
# show the null values
plt.title('heatmap for null value')
sns.heatmap(data.isnull())
# Out:
# <AxesSubplot:title={'center':'heatmap for null value'}>

# %%
heatmap = sns.heatmap(fenc.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation of feature', fontdict={'fontsize':30}, pad=30);

# %%
fenc.corr()
# Out:
#                        gender  hsc_pass_year  uni_admssn_year  curr_sem  \
# gender               1.000000       0.031094         0.031993 -0.037609
# hsc_pass_year        0.031094       1.000000         0.814510 -0.716821
# uni_admssn_year      0.031993       0.814510         1.000000 -0.867666
# curr_sem            -0.037609      -0.716821        -0.867666  1.000000
# merit_scholarship    0.057139       0.291131         0.365906 -0.375945
# use_uni_transport   -0.102192       0.008009         0.003301 -0.024342
# study_hour/day      -0.085403       0.002564        -0.024829  0.045078
# freq_study/day       0.024207      -0.018617        -0.007110  0.013043
# learning_mode       -0.132981       0.111410         0.109715 -0.096220
# have_smart_device   -0.053140       0.005213         0.004481 -0.016645
# have_pc              0.115897      -0.151291        -0.163123  0.168427
# social_media_time   -0.060608       0.098283         0.075045 -0.047784
# ...

# %% [markdown]
# ### Co-relation of targeted column within all column

# %%
fenc[fenc.columns[0:]].corr()['Student_status'][:].sort_values(ascending=False).to_frame()
# Out:
#                      Student_status
# Student_status             1.000000
# pre_sgpa                   0.664102
# cgpa                       0.539353
# attendance                 0.421995
# study_hour/day             0.180746
# team_task                  0.128325
# freq_study/day             0.125247
# english_skill              0.115500
# have_pc                    0.059193
# hsc_pass_year              0.045075
# learning_mode              0.044328
# have_smart_device          0.041829
# faculty_consultency        0.040501
# comp_cred                  0.037104
# gender                     0.030833
# merit_scholarship          0.030823
# curr_sem                   0.019868
# uni_admssn_year            0.018165
# self_dep                   0.015603
# curri_act                  0.002631
# use_uni_transport         -0.017459
# living_sts                -0.034573
# admission_diff            -0.042230
# phy_issue                 -0.067311
# kids                      -0.069643
# ...

# %%
# regression plot using seaborn
fig5 = plt.figure(figsize=(5,5))
sns.regplot(x=fenc.Student_status, y=fenc.attendance, color='blue', marker='+')
# sns.regplot(x=ds1.Z, y=ds1.A, color='magenta', marker='+')

# legend, title, and labels.
plt.legend(labels=['Students Status Vs Attendance'])
plt.title('Relationship', size=10)
plt.xlabel('X', size=10)
plt.ylabel('Y', size=10);

# %%
#co-relation using heatmap

plt.figure(figsize=(50,50))
sns.set_theme(style="white")
corr = fenc.corr()
heatmap1 = sns.heatmap(corr, annot=True, cmap="Blues", fmt='.3g')

# %%
#saving the graph
h_corr = heatmap1.get_figure()
h_corr.savefig("Heat_map_corr.png",dpi=300)

# %%
plt.figure(figsize=(8,8))
sns.set_theme(style="white")
corr = fenc.corr()
heatmap = sns.heatmap(corr, cmap="coolwarm")

# %%
#saving the graph
h_corr = heatmap.get_figure()
h_corr.savefig("Heat_map_corr_warm.png",dpi=300)

# %%
#Co-relation using Diagonal correlation matrix

sns.set_theme(style="white")
corr = fenc.corr()
mask = np.triu(fenc.corr())
f, ax = plt.subplots(figsize=(20, 20))
cmap = sns.color_palette("Blues")

fig=sns.heatmap(corr, 
            mask=mask, 
            cmap=cmap, 
            vmax=.3, 
            center=0,
            square=True, 
            linewidths=3, 
            cbar_kws={"shrink": .5}
           )

# %%
#saving the graph
h_corr = fig.get_figure()
h_corr.savefig("Diagonal_corr_graph.png",dpi=300)

# %%
fenc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    int64
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    int64
#  10  use_uni_transport    675 non-null    int64
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    int64
#  14  have_smart_device    675 non-null    int64
# ...

# %%
pd.value_counts(fenc['hometown'])
# Out:
# Gazipur        85
# Dhaka          45
# Cumilla        44
# Barishal       25
# Tangail        25
#                ..
# Patgram         1
# Bikrampur       1
# Munshiganj      1
# Joypurhat       1
# Barguna         1
# Name: hometown, Length: 88, dtype: int64

# %%
plt.figure(figsize = (20,18))
plt.title('CSE students performance',bar_chart('Student_status'))
plt.xlabel("Students Status")
plt.ylabel("No. of students")
plt.savefig('CSE students performance.png')
plt.show()

#fig1=bar_chart('Student_status')
#fig1.savefig("Histogram_students_status.jpg")

#saving the graph
#h_corr = heatmap1.get_figure()
#h_corr.savefig("Heat_map_corr.png",dpi=300)

# %%
# creating the dataset
data = {'C':fenc[], 'C++':15, 'Java':30,
        'Python':35}
courses = list(data.keys())
values = list(data.values())
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(courses, values, color ='maroon',
        width = 0.4)
 
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %%
plt.title('Customized histogram')
fenc['Student_status'].hist(bins=5);

# %%
fenc['Student_status'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ### Bar Chart

# %%
#encoding for student status -> Excellent = 4, Good = 3, Average = 2, Poor = 1, probation = 0
#fenc['Student_status'].replace('Excellent',4,inplace=True)
#fenc['Student_status'].replace('Good',3,inplace=True)
#fenc['Student_status'].replace('Average',2,inplace=True)
#fenc['Student_status'].replace('Poor',1,inplace=True)
#fenc['Student_status'].replace('Probation',0,inplace=True)

# %%
#bar chart depending on students performance
def bar_chart(feature):
    Excellent = fenc[fenc['Student_status']==4][feature].value_counts()
    Good = fenc[fenc['Student_status']==3][feature].value_counts()
    Average = fenc[fenc['Student_status']==2][feature].value_counts()
    Poor = fenc[fenc['Student_status']==1][feature].value_counts()
    Probation = fenc[fenc['Student_status']==0][feature].value_counts()
    
    
    dfbc = pd.DataFrame([Excellent,Good,Average,Poor,Probation])
    dfbc.index = ['Excellent','Good','Average','Poor','Probation']
    dfbc.plot(kind='bar',stacked=True,figsize=(12,8))

# %%
fenc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    int64
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    int64
#  10  use_uni_transport    675 non-null    int64
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    int64
#  14  have_smart_device    675 non-null    int64
# ...

# %%
#bar_chart('gender')

plt.figure(figsize = (20,18))
plt.title(bar_chart('gender'))
plt.xlabel("Students Status")
plt.ylabel("No. of students")

plt.savefig('Gender.png')
plt.show()

# %%
#bar_chart('social_media_time')
#bar_chart('gender')

plt.figure(figsize = (20,18))
plt.title(bar_chart('social_media_time'))
plt.xlabel("Students Status")
plt.ylabel("No. of students")

plt.savefig('Gender.png')
plt.show()

# %%
bar_chart('self_dep')

# %%
bar_chart('political_eng')

# %%
bar_chart('phy_disb')

# %%
bar_chart('self_dep')

# %%
bar_chart('relation_sts')

# %%
bar_chart('curri_act')

# %%
bar_chart('faculty_consultency')

# %%
bar_chart('learning_mode')

# %% [markdown]
# <h1><center>Model Evalution<center><h1>

# %%
final_df = fenc

# %%
final_df.head()
# Out:
#          id                      name  gender age  hsc_pass_year  \
# 0  18303059                Abu Raihan       1  24           2016
# 1  21203066       Jahidul Islam Anik        1  22           2020
# 2  20103005  Symu Alahi Jannat Abonti       0  21           2019
# 3  21203080     Hedayetul Islam Anik        1  20           2020
# 4  21203032           Abu Aslam Mithu       1  22           2019
#
#    uni_admssn_year uni_name program  curr_sem  merit_scholarship  ...  \
# 0             2018    IUBAT    BCSE        12                  1  ...
# 1             2021   IUBAT     BCSE         4                  1  ...
# 2             2020    IUBAT    BCSE         5                  0  ...
# 3             2021    IUBAT    BCSE         4                  1  ...
# 4             2021    IUBAT    BCSE         4                  1  ...
#
#    phy_issue  team_task  phy_disb  self_dep  admission_diff  Student_status  \
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    int64
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    int64
#  10  use_uni_transport    675 non-null    int64
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    int64
#  14  have_smart_device    675 non-null    int64
# ...

# %% [markdown]
# #### Outlier Lookup

# %%
#see the outlier in CGPA column
final_df['cgpa'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
final_df.plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
#see the outlier in SGPA column
final_df['pre_sgpa'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
#see the outlier in social_media_time column
final_df['social_media_time'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### lets see data Distribution

# %%
#distribution of students status
plt.title('Students_status Distribution')
plot = sns.distplot(final_df["Student_status"],hist=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#distribution of Cgpa
plt.title('CGPA Distribution')
plot = sns.distplot(final_df["cgpa"],hist=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#distribution of pre_sgpa
plot = sns.distplot(final_df["pre_sgpa"],hist=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#distribution of attendance
plot = sns.distplot(final_df["attendance"],hist=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 37 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   id                   675 non-null    object
#  1   name                 675 non-null    object
#  2   gender               675 non-null    int64
#  3   age                  675 non-null    object
#  4   hsc_pass_year        675 non-null    int32
#  5   uni_admssn_year      675 non-null    int32
#  6   uni_name             675 non-null    object
#  7   program              675 non-null    object
#  8   curr_sem             675 non-null    int64
#  9   merit_scholarship    675 non-null    int64
#  10  use_uni_transport    675 non-null    int64
#  11  study_hour/day       675 non-null    int64
#  12  freq_study/day       675 non-null    int64
#  13  learning_mode        675 non-null    int64
#  14  have_smart_device    675 non-null    int64
# ...

# %%
final_df.drop(["hometown"],axis=1,inplace=True)

# %%
final_df.drop(["program"],axis=1,inplace=True)

# %%
final_df.drop(["uni_name"],axis=1,inplace=True)

# %%
final_df.drop(["age"],axis=1,inplace=True)

# %%
final_df.drop(["id"],axis=1,inplace=True)

# %%
final_df.drop(["name"],axis=1,inplace=True)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               675 non-null    int64
#  1   hsc_pass_year        675 non-null    int32
#  2   uni_admssn_year      675 non-null    int32
#  3   curr_sem             675 non-null    int64
#  4   merit_scholarship    675 non-null    int64
#  5   use_uni_transport    675 non-null    int64
#  6   study_hour/day       675 non-null    int64
#  7   freq_study/day       675 non-null    int64
#  8   learning_mode        675 non-null    int64
#  9   have_smart_device    675 non-null    int64
#  10  have_pc              675 non-null    int64
#  11  social_media_time    675 non-null    int64
#  12  english_skill        675 non-null    int64
#  13  attendance           675 non-null    int64
#  14  probation            675 non-null    int64
# ...

# %% [markdown]
# # train test spliting

# %%
# Split into train test set
from sklearn.model_selection import train_test_split
train, test = train_test_split(final_df, test_size=0.2, random_state=42)

# %%
train.shape,test.shape
# Out:
# ((540, 31), (135, 31))

# %%
y_test = train['Student_status']
X_test = train.drop('Student_status', axis=1)

# %%
# preparing data for modeling
target = train['Student_status'] #target-> y_train
train_data = train.drop('Student_status', axis=1) #train_data -> X_train

# %%
target.shape, train_data.shape
# Out:
# ((540,), (540, 30))

# %% [markdown]
# ## Modeling

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
k_fold = KFold(n_splits=10, shuffle=True, random_state=42)

# %% [markdown]
# # Decision Tree

# %%
clf = DecisionTreeClassifier()
scoring = 'accuracy'
DTscore = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=2, scoring=scoring)
print(score)
# Out:
# [0.96296296 0.94444444 0.94444444 0.96296296 0.94444444 0.88888889
#  0.90740741 0.88888889 0.92592593 0.98148148]

# %%
# decision tree score
round(np.mean(DTscore)*100,2)
# Out:
# 92.78

# %% [markdown]
# ## Logistic Regresion

# %%
clf = LogisticRegression()
LRscore = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(LRscore)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
# Logistic Regression score
round(np.mean(LRscore)*100, 2)
# Out:
# 47.96

# %%
clf.fit(train_data, target)
clf.score(X_test, y_test)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 0.5037037037037037

# %% [markdown]
# ## Random Forest

# %%
clf = RandomForestClassifier(n_estimators=13)
scoring = 'accuracy'
RFscore = cross_val_score(clf, train_data, target, cv=k_fold, n_jobs=1, scoring=scoring)
print(score)
from sklearn.metrics import confusion_matrix

cm1 = confusion_matrix(target, y_test)
print(classification_report(target, y_test, final_df['']))
# true write data values in each cell of the matrix
sns.heatmap(cm1,annot=True)
plt.savefig('confusionRF.png')
# Out:
# [0.87037037 0.81481481 0.83333333 0.94444444 0.81481481 0.92592593
#  0.87037037 0.83333333 0.88888889 0.92592593]
#               precision    recall  f1-score   support
#
#            0       0.93      0.63      0.75        63
#            1       0.75      0.71      0.73       107
#            2       0.54      0.48      0.51       121
#            3       0.62      0.82      0.70       192
#            4       0.59      0.35      0.44        57
#
#     accuracy                           0.65       540
#    macro avg       0.69      0.60      0.63       540
# weighted avg       0.66      0.65      0.64       540

# %%
# Random Forest score
round(np.mean(RFscore)*100, 2)
# Out:
# 85.56

# %% [markdown]
# ## Naive Bayes¶

# %%
from sklearn.naive_bayes import GaussianNB
clf = GaussianNB()
cross_val = KFold(n_splits=10,shuffle = True, random_state=42)
NBscore = cross_val_score(clf, train_data, target, cv=cross_val, scoring=scoring)
print(NBscore)
# Out:
# [0.68518519 0.53703704 0.61111111 0.59259259 0.55555556 0.62962963
#  0.51851852 0.61111111 0.55555556 0.53703704]

# %%
# Naive Bayes score
round(np.mean(NBscore)*100, 2)
# Out:
# 58.33

# %%
clf.fit(train_data, target)
clf.score(X_test, y_test)
# Out:
# 0.6425925925925926

# %%
final_df.to_csv("final_DF.csv")

# %% [markdown]
# #### Evaluation of Gaussian Naive Bayes Classifier

# %%
from sklearn.metrics import confusion_matrix

# passing actual and predicted values
cm = confusion_matrix(target, y_test)
print(classification_report(target, y_test))
# true write data values in each cell of the matrix
sns.heatmap(cm,annot=True)
plt.savefig('confusion.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12284/1652278613.py in <module>
#       3 # passing actual and predicted values
#       4 cm = confusion_matrix(target, y_test)
# ----> 5 print(classification_report(cm))
#       6 # true write data values in each cell of the matrix
#       7 sns.heatmap(cm,annot=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# TypeError: classification_report() missing 1 required positional argument: 'y_pred'

# %%
pd.value_counts(final_df['Student_status'])
# Out:
# 3    230
# 2    159
# 1    142
# 0     73
# 4     71
# Name: Student_status, dtype: int64

# %% [markdown]
# #### Classification Report

# %%
# importing classification report
from sklearn.metrics import classification_report

# printing the report
print(classification_report(y_test,target))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        62
#            1       1.00      1.00      1.00       109
#            2       1.00      1.00      1.00       121
#            3       1.00      1.00      1.00       190
#            4       1.00      1.00      1.00        58
#
#     accuracy                           1.00       540
#    macro avg       1.00      1.00      1.00       540
# weighted avg       1.00      1.00      1.00       540

# %% [markdown]
# ## K-nearest Neighbor

# %%
#from sklearn.neighbors import KNeighborsClassifier
dtest = KNeighborsClassifier()
# training the model
dtest.fit(train_data, target)

# testing the model
y_test = dtest.predict(X_test)
print(accuracy_score(target, y_test))
# Out:
# 0.6925925925925925

# %%
dtest.fit(train_data, y_test)
dtest.score(X_test, y_test)
# Out:
# 0.9111111111111111

# %%
y_test
# Out:
# array([3, 0, 1, 3, 1, 1, 2, 3, 3, 3, 3, 2, 0, 2, 3, 3, 3, 1, 4, 3, 1, 2,
#        1, 0, 2, 3, 4, 4, 3, 2, 0, 3, 2, 2, 1, 2, 3, 0, 3, 2, 3, 3, 3, 3,
#        3, 4, 2, 1, 1, 3, 3, 1, 3, 1, 3, 2, 3, 4, 3, 2, 2, 2, 3, 3, 4, 2,
#        3, 3, 0, 2, 1, 1, 3, 3, 1, 0, 3, 2, 3, 1, 3, 1, 4, 3, 2, 3, 3, 3,
#        3, 2, 0, 2, 3, 0, 0, 3, 3, 3, 3, 2, 2, 1, 3, 3, 3, 3, 3, 3, 3, 3,
#        1, 3, 3, 3, 3, 2, 3, 4, 3, 1, 1, 2, 0, 3, 3, 3, 3, 3, 0, 2, 3, 0,
#        2, 3, 1, 4, 2, 3, 3, 1, 3, 3, 3, 3, 2, 3, 4, 3, 1, 3, 0, 3, 4, 3,
#        3, 2, 3, 3, 1, 0, 3, 3, 2, 0, 2, 3, 2, 3, 1, 0, 1, 1, 1, 2, 1, 1,
#        3, 3, 1, 3, 0, 3, 3, 0, 3, 2, 3, 3, 2, 1, 2, 3, 3, 3, 2, 3, 3, 1,
#        3, 0, 2, 2, 1, 1, 2, 1, 3, 4, 1, 3, 2, 1, 2, 1, 2, 1, 2, 1, 3, 4,
#        4, 1, 3, 3, 1, 2, 3, 2, 3, 1, 3, 3, 0, 2, 3, 3, 4, 2, 3, 0, 3, 2,
#        3, 0, 2, 3, 3, 3, 3, 3, 2, 2, 2, 4, 3, 2, 1, 2, 4, 2, 1, 3, 3, 4,
#        3, 2, 3, 3, 3, 3, 3, 3, 2, 1, 1, 3, 2, 4, 2, 4, 1, 2, 3, 3, 2, 0,
# ...

# %% [markdown]
# ### Support-vector Machine

# %%
 
svm = SVC(kernel="linear")

# Training the model on the training data and labels
svm.fit(train_data, target)

# Using the model to predict the labels of the test data
target = svm.predict(X_test)

# Evaluating the accuracy of the model using the sklearn functions
accuracy = accuracy_score(y_test,target)*100
confusion_mat = confusion_matrix(y_test,target)

# Printing the results
print("Accuracy for SVM is:",accuracy)
print("Confusion Matrix")
print(confusion_mat)
# Out:
# Accuracy for SVM is: 65.0
# Confusion Matrix
# [[ 40   1   1   1   0]
#  [  8  76  16   1   0]
#  [  6  20  58  21   2]
#  [  9   9  45 157  35]
#  [  0   1   1  12  20]]

# %%
svm.fit(train_data, y_test)
svm.score(X_test, y_test)
# Out:
# 0.7870370370370371

# %%
print(classification_report(target, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.63      0.75        63
#            1       0.75      0.71      0.73       107
#            2       0.54      0.48      0.51       121
#            3       0.62      0.82      0.70       192
#            4       0.59      0.35      0.44        57
#
#     accuracy                           0.65       540
#    macro avg       0.69      0.60      0.63       540
# weighted avg       0.66      0.65      0.64       540

# %% [markdown]
# <h1><center>Methodology

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 675 entries, 0 to 674
# Data columns (total 31 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   gender               675 non-null    int64
#  1   hsc_pass_year        675 non-null    int32
#  2   uni_admssn_year      675 non-null    int32
#  3   curr_sem             675 non-null    int64
#  4   merit_scholarship    675 non-null    int64
#  5   use_uni_transport    675 non-null    int64
#  6   study_hour/day       675 non-null    int64
#  7   freq_study/day       675 non-null    int64
#  8   learning_mode        675 non-null    int64
#  9   have_smart_device    675 non-null    int64
#  10  have_pc              675 non-null    int64
#  11  social_media_time    675 non-null    int64
#  12  english_skill        675 non-null    int64
#  13  attendance           675 non-null    int64
#  14  probation            675 non-null    int64
# ...

# %%
pd.value_counts(final_df['Student_status'])
# Out:
# 3    230
# 2    159
# 1    142
# 0     73
# 4     71
# Name: Student_status, dtype: int64
